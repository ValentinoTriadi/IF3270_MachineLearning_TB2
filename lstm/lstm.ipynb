# %%
# Import library
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt

from preprocessing import LSTMPreprocess

# %%
# Load Dataset
train_set = pd.read_csv("data/train.csv")
valid_set = pd.read_csv("data/valid.csv")
test_set = pd.read_csv("data/test.csv")

# %%
# Preprocess dataset (SPLIT)
label_map = {"positive": 0, "neutral": 1, "negative": 2}
num_classes = len(label_map)

print("Memproses dataset...")
train_texts = train_set["text"]
train_labels = np.array(train_set["label"].map(lambda x: label_map[x]))

test_texts = test_set["text"]
test_labels = np.array(test_set["label"].map(lambda x: label_map[x]))

valid_texts = valid_set["text"]
valid_labels = np.array(valid_set["label"].map(lambda x: label_map[x]))
# Out:
# Memproses dataset...

# %%
# Preprocess dataset (tokenization)
preprocess_cls = LSTMPreprocess()

train_token = preprocess_cls.tokenization(train_texts)
test_token = preprocess_cls.tokenization(test_texts)
valid_token = preprocess_cls.tokenization(valid_texts)

# %%
# Model

embedding_dim = 128  # Dimensi vektor embedding
lstm_units = 64  # Jumlah unit di layer LSTM
dropout_rate = 0.7  # Rate untuk dropout
vocab_size = 10000  # Vocabulary Size

# Bangun model Sequential Keras
model = keras.Sequential(
    [
        # 1. Embedding Layer
        keras.layers.Embedding(
            input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True
        ),
        
        # 2. Bidirectional LSTM Layer
        keras.layers.Bidirectional(keras.layers.LSTM(lstm_units, kernel_regularizer=keras.regularizers.l2(0.01))),
        
        # 2. Unidirectional LSTM Layer
        # keras.layers.LSTM(lstm_units, kernel_regularizer=keras.regularizers.l2(0.01)),

        # 3. Dropout Layer
        keras.layers.Dropout(dropout_rate),
        # 4. Dense Layer (Hidden)
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dropout(0.5),
        # 5. Dense Layer (Output)
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

model.build(input_shape=train_token.shape)

# Summary
model.summary()

# Kompilasi model
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (500, 100, 128)        │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (500, 128)             │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (500, 128)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (500, 32)              │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (500, 32)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (500, 3)               │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,383,043 (5.28 MB)
#  Trainable params: 1,383,043 (5.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train
epochs = 100
batch_size = 64

history = model.fit(
    train_token,
    train_labels,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(valid_token, valid_labels),
    callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.3265 - loss: 4.3542 - val_accuracy: 0.4300 - val_loss: 3.8904
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.3914 - loss: 3.7551 - val_accuracy: 0.4300 - val_loss: 3.3609
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.4457 - loss: 3.2362 - val_accuracy: 0.4500 - val_loss: 2.9081
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.4705 - loss: 2.7767 - val_accuracy: 0.3700 - val_loss: 2.5083
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.4889 - loss: 2.3874 - val_accuracy: 0.5100 - val_loss: 2.2036
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.5891 - loss: 2.0032 - val_accuracy: 0.4600 - val_loss: 1.9841
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7079 - loss: 1.6095 - val_accuracy: 0.5000 - val_loss: 1.9358
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.7774 - loss: 1.2956 - val_accuracy: 0.5100 - val_loss: 1.8884
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8290 - loss: 1.0291 - val_accuracy: 0.4600 - val_loss: 1.9753
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.9053 - loss: 0.8181 - val_accuracy: 0.4600 - val_loss: 1.8436
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9608 - loss: 0.6594 - val_accuracy: 0.5300 - val_loss: 1.9579
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9663 - loss: 0.5370 - val_accuracy: 0.5200 - val_loss: 2.1134
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9872 - loss: 0.3797 - val_accuracy: 0.5100 - val_loss: 2.2864
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9763 - loss: 0.3430 - val_accuracy: 0.4100 - val_loss: 2.3492
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9456 - loss: 0.4521 - val_accuracy: 0.4800 - val_loss: 2.4586

# %%
# Mendapatkan data history dari training
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy_values = history_dict['accuracy']
val_accuracy_values = history_dict['val_accuracy']

# Mendapatkan jumlah epoch
epochs = range(1, len(loss_values) + 1)

# Plot Training & Validation Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'bo-', label='Training loss')
plt.plot(epochs, val_loss_values, 'ro-', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot Training & Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy_values, 'bo-', label='Training acc')
plt.plot(epochs, val_accuracy_values, 'ro-', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
# Simpan bobot model
model.save("lstm_keras.h5")
print("Model Keras telah disimpan ke lstm_keras.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Keras telah disimpan ke lstm_keras.h5

# %%
# Evaluasi model pada data test
print("\nMengevaluasi model pada data test...")

loss, accuracy = model.evaluate(test_token, test_labels, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Menghitung F1 Score
y_pred_probs = model.predict(test_token)
test_labels_one_hot = tf.keras.utils.to_categorical(test_labels, num_classes=num_classes)

f1 = keras.metrics.F1Score(average='macro')
f1.update_state(test_labels_one_hot, y_pred_probs)
print(f"Test F1 Score: {f1.result().numpy():.4f}")



# Prediksi contoh
print("\nMelakukan prediksi pada beberapa data test...")
predictions = model.predict(test_token[:5])
predicted_labels = np.argmax(predictions, axis=1)

label_reverse_map = {v: k for k, v in label_map.items()}

for i in range(5):
    print(f"Ke-{i+1}")
    # Use original integer test_labels_int for comparison here
    print(f"Label Asli: {label_reverse_map[test_labels[i]]}")
    print(f"Label Prediksi: {label_reverse_map[predicted_labels[i]]}\n")
# Out:
# Mengevaluasi model pada data test...
# Test Loss: 2.0420
# Test Accuracy: 0.4050
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# Test F1 Score: 0.3872
#
# Melakukan prediksi pada beberapa data test...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ke-1
# Label Asli: positive
# Label Prediksi: positive
#
# Ke-2
# Label Asli: neutral
# Label Prediksi: negative
#
# Ke-3
# Label Asli: negative
# Label Prediksi: neutral
#
# Ke-4
# Label Asli: positive
# Label Prediksi: positive
#
# Ke-5
# Label Asli: neutral
# Label Prediksi: neutral
