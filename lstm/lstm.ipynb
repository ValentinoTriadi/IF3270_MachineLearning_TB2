# %%
# Import library
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt

from preprocessing import LSTMPreprocess

# %%
# Load Dataset
train_set = pd.read_csv("data/train.csv")
valid_set = pd.read_csv("data/valid.csv")
test_set = pd.read_csv("data/test.csv")

# %%
# Preprocess dataset (SPLIT)
label_map = {"positive": 0, "neutral": 1, "negative": 2}
num_classes = len(label_map)

print("Memproses dataset...")
train_texts = train_set["text"]
train_labels = np.array(train_set["label"].map(lambda x: label_map[x]))

test_texts = test_set["text"]
test_labels = np.array(test_set["label"].map(lambda x: label_map[x]))

valid_texts = valid_set["text"]
valid_labels = np.array(valid_set["label"].map(lambda x: label_map[x]))
# Out:
# Memproses dataset...

# %%
# Preprocess dataset (Tokenization)
preprocess_cls = LSTMPreprocess()

train_token = preprocess_cls.tokenization(train_texts)
test_token = preprocess_cls.tokenization(test_texts)
valid_token = preprocess_cls.tokenization(valid_texts)

# %%
# Model

embedding_dim = 128  # Dimensi vektor embedding
lstm_units = 32  # Jumlah unit di layer LSTM
dropout_rate = 0.7  # Rate untuk dropout
vocab_size = 10000  # Vocabulary Size

# Bangun model Sequential Keras
model = keras.Sequential(
    [
        # 1. Embedding Layer
        keras.layers.Embedding(
            input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True
        ),
        # 2. Bidirectional LSTM Layer
        # keras.layers.Bidirectional(keras.layers.LSTM(lstm_units, kernel_regularizer=keras.regularizers.l2(0.01))),
        
        # 2. Unidirectional LSTM Layer
        keras.layers.LSTM(
            lstm_units, kernel_regularizer=keras.regularizers.l2(0.01)
        ),
        # 3. Dropout Layer
        keras.layers.Dropout(dropout_rate),
        # 4. Dense Layer (Hidden)
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dropout(0.5),
        # 5. Dense Layer (Output)
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

model.build(input_shape=train_token.shape)

# Summary
model.summary()

# Kompilasi model
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
# Out:
# Model: "sequential_41"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_26 (Embedding)        │ (500, 100, 128)        │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_31 (LSTM)                  │ (500, 32)              │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_56 (Dropout)            │ (500, 32)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (500, 32)              │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_57 (Dropout)            │ (500, 32)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (500, 3)               │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,301,763 (4.97 MB)
#  Trainable params: 1,301,763 (4.97 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train
epochs = 100
batch_size = 64

history = model.fit(
    train_token,
    train_labels,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(valid_token, valid_labels),
    callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.3431 - loss: 2.3266 - val_accuracy: 0.3600 - val_loss: 2.1822
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.4146 - loss: 2.1339 - val_accuracy: 0.4200 - val_loss: 2.0109
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4715 - loss: 1.9629 - val_accuracy: 0.4100 - val_loss: 1.8599
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4595 - loss: 1.8105 - val_accuracy: 0.4500 - val_loss: 1.7243
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5295 - loss: 1.6529 - val_accuracy: 0.4400 - val_loss: 1.5840
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5747 - loss: 1.4717 - val_accuracy: 0.5100 - val_loss: 1.4661
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7112 - loss: 1.2123 - val_accuracy: 0.5100 - val_loss: 1.4910
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6771 - loss: 1.1085 - val_accuracy: 0.5100 - val_loss: 1.5112
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7595 - loss: 0.8773 - val_accuracy: 0.4900 - val_loss: 1.5304
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7475 - loss: 0.8005 - val_accuracy: 0.5000 - val_loss: 1.6070
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7612 - loss: 0.6823 - val_accuracy: 0.4800 - val_loss: 1.6790

# %%
# Mendapatkan data history dari training
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy_values = history_dict['accuracy']
val_accuracy_values = history_dict['val_accuracy']

# Mendapatkan jumlah epoch
epochs = range(1, len(loss_values) + 1)

# Plot Training & Validation Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'bo-', label='Training loss')
plt.plot(epochs, val_loss_values, 'ro-', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot Training & Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy_values, 'bo-', label='Training acc')
plt.plot(epochs, val_accuracy_values, 'ro-', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
# Simpan bobot model
model.save("lstm_keras.h5")
print("Model Keras telah disimpan ke lstm_keras.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Keras telah disimpan ke lstm_keras.h5

# %%
# Evaluasi model pada data test
print("\nMengevaluasi model pada data test...")

loss, accuracy = model.evaluate(test_token, test_labels, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Menghitung F1 Score
y_pred_probs = model.predict(test_token)
test_labels_one_hot = tf.keras.utils.to_categorical(test_labels, num_classes=num_classes)

f1 = keras.metrics.F1Score(average='macro')
f1.update_state(test_labels_one_hot, y_pred_probs)
print(f"Test F1 Score: {f1.result().numpy():.4f}")



# Prediksi contoh
print("\nMelakukan prediksi pada beberapa data test...")
predictions = model.predict(test_token[:5])
predicted_labels = np.argmax(predictions, axis=1)

label_reverse_map = {v: k for k, v in label_map.items()}

for i in range(5):
    print(f"Ke-{i+1}")
    # Use original integer test_labels_int for comparison here
    print(f"Label Asli: {label_reverse_map[test_labels[i]]}")
    print(f"Label Prediksi: {label_reverse_map[predicted_labels[i]]}\n")
# Out:
# Mengevaluasi model pada data test...
# Test Loss: 1.4604
# Test Accuracy: 0.5275
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Test F1 Score: 0.4004
#
# Melakukan prediksi pada beberapa data test...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Ke-1
# Label Asli: positive
# Label Prediksi: positive
#
# Ke-2
# Label Asli: neutral
# Label Prediksi: negative
#
# Ke-3
# Label Asli: negative
# Label Prediksi: positive
#
# Ke-4
# Label Asli: positive
# Label Prediksi: positive
#
# Ke-5
# Label Asli: neutral
# Label Prediksi: negative
